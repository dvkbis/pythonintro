# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def hasPathSum(self, root: Optional[TreeNode], targetSum: int) -> bool:
        if not root:
            return False
            
        def dfs(node, sum_path):
            sum_path += node.val

            if not node.left and not node.right:
                return True if sum_path == targetSum else False

            
            if node.left and dfs(node.left, sum_path):
                return True
            if node.right and dfs(node.right, sum_path):
                return True
            
            return False

        return dfs(root, 0)

# %%
combinations = [2,3,4]
abc = combinations[:]
abc[0] = 10
print(combinations)
# Out:
# [2, 3, 4]
