# %%
def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
    if not head:
        return head
    
    cur = head

    while cur.next:
        next = cur.next
        if cur.val == next.val:
            cur.next = next.next
        else:
            cur = next

    return head
