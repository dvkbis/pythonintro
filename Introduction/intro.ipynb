# %% [markdown]
# # Informations sur python
# - Polyvalent / Language interprêté / Accessible
# - Language haut niveau / Proche de l'anglais
# - Peut faire de la POO
# - Typage dynamique
# - Executé en console
# - Etendu au language C / C++ (Ecrire du code en C et le faire fonctionner avec python)
# - Personnalisé / Modifié des choses déjà existantes
# - Utilisé par les Data Analyst (Numpy,..)
# - PyCharm (alternative IDE)

# %% [markdown]
# # Indentation
# - Obligatoire
# - Infos sur PEP08
# - bloc de code défini par ":" et suivi d'une indentation

# %%
if True:
    print('hi')

# %% [markdown]
# # Import / Implementation / Appel

# %%
# import de fichiers
import math

# implementation
def Test():
    print('hi')

# Appel
Test()

# %%
""" commentaires """
# commentaires
''' commentaires '''
