# %% [markdown]
# ## Convertir une valeur
# - utiliser le constructeur du type

# %%
# Conversion int
nb1 = int("10")
nb2 = int("10")
print(f"resultat = {nb1 + nb2}")

# %%
# Conversion boolean
a = 5
b = 10
a_greater = a > b
zero = bool(0)
un = bool(1)

print(a_greater)
print(a)
print(b)

# %%
# Conversion en float
a = 3
b = 10
result_int = b / 3

print(type(result_int))
print(result_int)
# Out:
# <class 'float'>
# 3.3333333333333335

# %%
# Conversion string
a = 3
b = 10
result_str= str(a + b)
print(result_str)
# print( 59 + " p") => concaténation int + str = erreur
# Out:
# 13
