# %% [markdown]
# # Match Structure

# %%
def describe_value(value):
    match value:
        case 0:
            return "Zero"
        case 1 | 2:
            return "One or Two"
        case int() as number if number > 2:
            return "A positive integer greater than two"
        case str() as text:
            return f"A string: {text}"
        case _:
            return "Something else"

for test_value in [0, 1, 5, "hello", 3.14]:
    print(test_value, "->", describe_value(test_value))

# %% [markdown]
# # if-ifel-if structure

# %%
def evaluate_number(n):
    if n < 0:
        return "Negative"
    elif n == 0:
        return "Zero"
    elif n < 10:
        return "Small positive"
    else:
        return "Large positive"

for value in [-5, 0, 3, 12]:
    print(value, "->", evaluate_number(value))

# %% [markdown]
# # Ternary Operator

# %%
x = 10
result = "Even" if x % 2 == 0 else "Odd"
print(x, "is", result)

y = 3
message = "Positive" if y > 0 else "Non-positive"
print(y, "is", message)

# %% [markdown]
# # Condition python
#  **Valeurs False par défaut si aucune valeur**
#
# - []
# - ""
# - 0
# - None

# %%
print(bool(None))
# Out:
# False
