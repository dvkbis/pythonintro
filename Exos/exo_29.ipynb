# %%
# 1
input1 = input("Mot 1 : ")
input2 = input("Mot 2 : ")
print(input1, input2, sep = " -- ")
# Out:
# Hello -- World

# %%
# 2
print("C", "Python", "C++", "Java", sep = " ! \n", end= " !")
# Out:
# C !
# Python !
# C++ !
# Java!

# %%
# 3
input1 = input("Mot 1 : ")
input2 = input("Mot 2 : ")
print(input1, input2, sep = "")
print("T : ", input1 + input2)
# Out:
# T :

# %%
# 4
input1 = int(input("Nombre 1 : "))
input2 = int(input("Nombre 2 : "))
res = f"res : {input1 + input2}"
print ("Resultat :", input1 + input2)
print(res)
# Out:
# Resultat : 12
# res : 12

# %%
# 5
a = 10
b = 20
c = 30
print(a, b, c, sep = " + ", end = f" = {a + b + c}" )
# Out:
# 10 + 20 + 30 = 60
