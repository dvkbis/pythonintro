# %% [markdown]
# 3. Considérons : A = 13 / B = 5/ C=True/D=not(C).Donnez le résultat pour chacune de ces instructions :
# ▪ (A > 10) and (B < 20)
# TRUE and TRUE => TRUE
# ▪ (C != 40) or (D >= 100)
#     TRUE
# ▪ (A == 2) and (not (B > 15))
# FALSE
# ▪ (C > 50) or (not (D < 200))
#     FALSE       TRUE    => TRUE
# ▪ ((A < B) and (C > 30)) or (D == 270)
#    ( FALSE              ) or     FALSE
#    => FALSE
# ▪ not ((A * B) > 100)
#        not( FALSE )
#     => TRUE
# ▪ ((B == 15) or ((C > 60) and (A < 5)))
#     FALSE           FALSE           => FALSE
# ▪ (((B == 15) or ((C > 60) and (A < 5))) and (A < B)) or (not (B == 9))
#     (FALSE           FALSE                       FALSE)
#                                 FALSE                or          TRUE
#     => TRUE

# %%
""" Imaginez et réalisez une méthode manuelle permettant d'inverser le contenu d'une variable entière sans utiliser de
variable temporaire"""

n = 50
n = 1 / n

# %%
""" Écrivez un programme Python convertissant un nombre de secondes en jours, heures, minutes et seconds
correspondants. Exemple : 4561 secondes correspondent à 0 jour, 1 heure, 16 minutes et 1 seconde. Réfléchissez à la
méthode à utiliser, puis réalisez l'algorithme en Python. Testez-le ensuite pour vérifier sa validité"""

n = 87000
# min = 60
# hours = 3600
# day = 86400
day = n // 86400
n %= 86400
hours = n // 3600
n %= 3600
min = n // 60
sec = n % 60 
print(f"{day} jour(s), {hours} heure(s), {min} minute(s), {sec} seconde(s)")
# Out:
# 1 jour(s), 0 heure(s), 10 minute(s), 0 seconde(s)
